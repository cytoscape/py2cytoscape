# %%
from py2cytoscape.data import Table

# %%
my_table = Table.read('ttest.csv')

# %%
my_table.push(1111)
# Out:
# [
#     {
#         "dm": 0.0823826155,
#         "Unnamed: 0": "IG_1070_1689385_1697378_fwd_f_st",
#         "p.value": 0.0491333361,
#         "statistic": 2.4597919916
#     },
#     {
#         "dm": -0.0463989172,
#         "Unnamed: 0": "IG_10_10495_10642_rev_st",
#         "p.value": 0.0237214275,
#         "statistic": -3.0093159131
#     },
#     {
#         "dm": -0.1696264644,
#         "Unnamed: 0": "IG_1110_1744617_1744723_fwd_st",
#         "p.value": 0.0455917914,
#         "statistic": -2.5150368793
#     },
#     {
#         "dm": 0.3687731132,
#         "Unnamed: 0": "IG_1145_1805715_1805819_fwd_st",
#         "p.value": 0.0119810827,
#         "statistic": 3.5562628204
#     },
#     {
#         "dm": -0.2767479519,
#         "Unnamed: 0": "IG_1189_1874879_1874911_fwd_st",
#         "p.value": 0.028210674,
#         "statistic": -2.8758422095
#     },
#     {
#         "dm": -0.2976390329,
#         "Unnamed: 0": "IG_1346_2085091_2085350_rev_st",
# ...
